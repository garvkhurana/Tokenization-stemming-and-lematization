# %% [markdown]
# The meaning of tokenization means that first converting the corpus or the paragrapoh into the sentances and then converting the sentances into the words and then filtering them andf then converting them into verctors to make it easy for the model to understand it it will make the sentances on the basis of full stops(.)and the punctuation marks(!)

# %%
corpus="""Avul Pakir Jainulabdeen Abdul Kalam BR was an Indian aerospace scientist and statesman who served as the 11th president of India from 2002 to 2007. He was born and raised in Rameswaram, Tamil Nadu and studied physics and aerospace engineering
He was born and raised in Rameswaram, Tamil Nadu and studied physics and aerospace engineering. He spent the next four decades as a scientist and science administrator, mainly at the Defence Research and Development Organisation (DRDO) and Indian Space Research Organisation (ISRO) and was intimately involved in India's civilian space programme and military missile development efforts.[1] He thus came to be known as the Missile Man of India for his work on the development of ballistic missile and launch vehicle technology.[2][3][4] He also played a pivotal organisational, technical, and political role in India's Pokhran-II nuclear tests in 1998, the first since the original nuclear test by India in 1974
"""

# %%
corpus
# Out:
# "Avul Pakir Jainulabdeen Abdul Kalam BR was an Indian aerospace scientist and statesman who served as the 11th president of India from 2002 to 2007. He was born and raised in Rameswaram, Tamil Nadu and studied physics and aerospace engineering\nHe was born and raised in Rameswaram, Tamil Nadu and studied physics and aerospace engineering. He spent the next four decades as a scientist and science administrator, mainly at the Defence Research and Development Organisation (DRDO) and Indian Space Research Organisation (ISRO) and was intimately involved in India's civilian space programme and military missile development efforts.[1] He thus came to be known as the Missile Man of India for his work on the development of ballistic missile and launch vehicle technology.[2][3][4] He also played a pivotal organisational, technical, and political role in India's Pokhran-II nuclear tests in 1998, the first since the original nuclear test by India in 1974\n"

# %%
import nltk

# %%
from nltk.tokenize import sent_tokenize

# %%
sent_tokenize(corpus)
# Out:
# ['Avul Pakir Jainulabdeen Abdul Kalam BR was an Indian aerospace scientist and statesman who served as the 11th president of India from 2002 to 2007.',
#  'He was born and raised in Rameswaram, Tamil Nadu and studied physics and aerospace engineering\nHe was born and raised in Rameswaram, Tamil Nadu and studied physics and aerospace engineering.',
#  "He spent the next four decades as a scientist and science administrator, mainly at the Defence Research and Development Organisation (DRDO) and Indian Space Research Organisation (ISRO) and was intimately involved in India's civilian space programme and military missile development efforts.",
#  '[1] He thus came to be known as the Missile Man of India for his work on the development of ballistic missile and launch vehicle technology.',
#  "[2][3][4] He also played a pivotal organisational, technical, and political role in India's Pokhran-II nuclear tests in 1998, the first since the original nuclear test by India in 1974"]

# %% [markdown]
# here it has converted the paragraph into the indivisual sentances

# %% [markdown]
# now its time to convert them into words

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Avul',
#  'Pakir',
#  'Jainulabdeen',
#  'Abdul',
#  'Kalam',
#  'BR',
#  'was',
#  'an',
#  'Indian',
#  'aerospace',
#  'scientist',
#  'and',
#  'statesman',
#  'who',
#  'served',
#  'as',
#  'the',
#  '11th',
#  'president',
#  'of',
#  'India',
#  'from',
#  '2002',
#  'to',
#  '2007',
#  '.',
#  'He',
#  'was',
#  'born',
#  'and',
#  'raised',
#  'in',
#  'Rameswaram',
#  ',',
#  'Tamil',
#  'Nadu',
#  'and',
#  'studied',
#  'physics',
#  'and',
#  'aerospace',
#  'engineering',
#  'He',
#  'was',
#  'born',
#  'and',
#  'raised',
#  'in',
#  'Rameswaram',
#  ',',
#  'Tamil',
#  'Nadu',
#  'and',
#  'studied',
#  'physics',
#  'and',
#  'aerospace',
#  'engineering',
#  '.',
#  'He',
#  'spent',
#  'the',
#  'next',
#  'four',
#  'decades',
#  'as',
#  'a',
#  'scientist',
#  'and',
#  'science',
#  'administrator',
#  ',',
#  'mainly',
#  'at',
#  'the',
#  'Defence',
#  'Research',
#  'and',
#  'Development',
#  'Organisation',
#  '(',
#  'DRDO',
#  ')',
#  'and',
# ...

# %% [markdown]
# we can also use punct tokenizer to get a more precise version of word tokenization

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Avul',
#  'Pakir',
#  'Jainulabdeen',
#  'Abdul',
#  'Kalam',
#  'BR',
#  'was',
#  'an',
#  'Indian',
#  'aerospace',
#  'scientist',
#  'and',
#  'statesman',
#  'who',
#  'served',
#  'as',
#  'the',
#  '11th',
#  'president',
#  'of',
#  'India',
#  'from',
#  '2002',
#  'to',
#  '2007',
#  '.',
#  'He',
#  'was',
#  'born',
#  'and',
#  'raised',
#  'in',
#  'Rameswaram',
#  ',',
#  'Tamil',
#  'Nadu',
#  'and',
#  'studied',
#  'physics',
#  'and',
#  'aerospace',
#  'engineering',
#  'He',
#  'was',
#  'born',
#  'and',
#  'raised',
#  'in',
#  'Rameswaram',
#  ',',
#  'Tamil',
#  'Nadu',
#  'and',
#  'studied',
#  'physics',
#  'and',
#  'aerospace',
#  'engineering',
#  '.',
#  'He',
#  'spent',
#  'the',
#  'next',
#  'four',
#  'decades',
#  'as',
#  'a',
#  'scientist',
#  'and',
#  'science',
#  'administrator',
#  ',',
#  'mainly',
#  'at',
#  'the',
#  'Defence',
#  'Research',
#  'and',
#  'Development',
#  'Organisation',
#  '(',
#  'DRDO',
#  ')',
#  'and',
# ...

# %% [markdown]
# this all is a part of text preprocessing or text cleaning to get a clean and pure data to feed our model

# %%
from nltk.tokenize import blankline_tokenize

# %%
blankline_tokenize(corpus)
# Out:
# ["Avul Pakir Jainulabdeen Abdul Kalam BR was an Indian aerospace scientist and statesman who served as the 11th president of India from 2002 to 2007. He was born and raised in Rameswaram, Tamil Nadu and studied physics and aerospace engineering\nHe was born and raised in Rameswaram, Tamil Nadu and studied physics and aerospace engineering. He spent the next four decades as a scientist and science administrator, mainly at the Defence Research and Development Organisation (DRDO) and Indian Space Research Organisation (ISRO) and was intimately involved in India's civilian space programme and military missile development efforts.[1] He thus came to be known as the Missile Man of India for his work on the development of ballistic missile and launch vehicle technology.[2][3][4] He also played a pivotal organisational, technical, and political role in India's Pokhran-II nuclear tests in 1998, the first since the original nuclear test by India in 1974\n"]

# %%
from nltk.tokenize import casual_tokenize

# %%
casual_tokenize(corpus)
# Out:
# ['Avul',
#  'Pakir',
#  'Jainulabdeen',
#  'Abdul',
#  'Kalam',
#  'BR',
#  'was',
#  'an',
#  'Indian',
#  'aerospace',
#  'scientist',
#  'and',
#  'statesman',
#  'who',
#  'served',
#  'as',
#  'the',
#  '11th',
#  'president',
#  'of',
#  'India',
#  'from',
#  '2002',
#  'to',
#  '2007',
#  '.',
#  'He',
#  'was',
#  'born',
#  'and',
#  'raised',
#  'in',
#  'Rameswaram',
#  ',',
#  'Tamil',
#  'Nadu',
#  'and',
#  'studied',
#  'physics',
#  'and',
#  'aerospace',
#  'engineering',
#  'He',
#  'was',
#  'born',
#  'and',
#  'raised',
#  'in',
#  'Rameswaram',
#  ',',
#  'Tamil',
#  'Nadu',
#  'and',
#  'studied',
#  'physics',
#  'and',
#  'aerospace',
#  'engineering',
#  '.',
#  'He',
#  'spent',
#  'the',
#  'next',
#  'four',
#  'decades',
#  'as',
#  'a',
#  'scientist',
#  'and',
#  'science',
#  'administrator',
#  ',',
#  'mainly',
#  'at',
#  'the',
#  'Defence',
#  'Research',
#  'and',
#  'Development',
#  'Organisation',
#  '(',
#  'DRDO',
#  ')',
#  'and',
# ...

# %%
from nltk.tokenize import line_tokenize

# %%
line_tokenize(corpus)
# Out:
# ['Avul Pakir Jainulabdeen Abdul Kalam BR was an Indian aerospace scientist and statesman who served as the 11th president of India from 2002 to 2007. He was born and raised in Rameswaram, Tamil Nadu and studied physics and aerospace engineering',
#  "He was born and raised in Rameswaram, Tamil Nadu and studied physics and aerospace engineering. He spent the next four decades as a scientist and science administrator, mainly at the Defence Research and Development Organisation (DRDO) and Indian Space Research Organisation (ISRO) and was intimately involved in India's civilian space programme and military missile development efforts.[1] He thus came to be known as the Missile Man of India for his work on the development of ballistic missile and launch vehicle technology.[2][3][4] He also played a pivotal organisational, technical, and political role in India's Pokhran-II nuclear tests in 1998, the first since the original nuclear test by India in 1974"]

# %%
from nltk.tokenize import MWETokenizer

# %%
token=MWETokenizer()

# %%
token.tokenize(corpus)
# Out:
# ['A',
#  'v',
#  'u',
#  'l',
#  ' ',
#  'P',
#  'a',
#  'k',
#  'i',
#  'r',
#  ' ',
#  'J',
#  'a',
#  'i',
#  'n',
#  'u',
#  'l',
#  'a',
#  'b',
#  'd',
#  'e',
#  'e',
#  'n',
#  ' ',
#  'A',
#  'b',
#  'd',
#  'u',
#  'l',
#  ' ',
#  'K',
#  'a',
#  'l',
#  'a',
#  'm',
#  ' ',
#  'B',
#  'R',
#  ' ',
#  'w',
#  'a',
#  's',
#  ' ',
#  'a',
#  'n',
#  ' ',
#  'I',
#  'n',
#  'd',
#  'i',
#  'a',
#  'n',
#  ' ',
#  'a',
#  'e',
#  'r',
#  'o',
#  's',
#  'p',
#  'a',
#  'c',
#  'e',
#  ' ',
#  's',
#  'c',
#  'i',
#  'e',
#  'n',
#  't',
#  'i',
#  's',
#  't',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  's',
#  't',
#  'a',
#  't',
#  'e',
#  's',
#  'm',
#  'a',
#  'n',
#  ' ',
#  'w',
#  'h',
#  'o',
#  ' ',
#  's',
#  'e',
#  'r',
#  'v',
#  'e',
#  'd',
#  ' ',
#  'a',
#  's',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  '1',
#  '1',
#  't',
#  'h',
#  ' ',
#  'p',
#  'r',
#  'e',
#  's',
#  'i',
#  'd',
#  'e',
#  'n',
#  't',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  'I',
#  'n',
# ...
